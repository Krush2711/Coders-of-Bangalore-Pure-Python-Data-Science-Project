# %% [markdown]
# # Coders of Bangalore
# You ask Sam Altman for a 2.2 billion USD in funding and he makes fun of you in public
#
# He asks you where you live and finally after talking to you, gives you a challenging task
#
# Collect raw instagram data of all openai followers
#
# Answer these questions:
#
# - Who has maximum posts
# - Who has maximum followers
# - Who follows maximum people
# - How many categories (Digital creators, Non profit foundation etc do we have) of how many people do we have?
#
# You have 24 hours
#
# You then ask for data - he laughs!

# %%
with open("initialdata.txt", encoding="utf") as f:
    data = f.read()

# %%
chunks = data.split('\n\n')

# %%
chunks = [c for c in chunks if len(c)>3]

# %%
print(chunks[1])
# Out:
# _anujsinghal
# 1,785 posts
# 681K followers
# 248 following
# Anuj Singhal
# Digital creator
# Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India
# Let’s talk about finance and life
# Contact: Singhalanuj1010@gmail.com
# hindi.cnbctv18.com/market-gurukul

# %%
print(chunks[0])
# Out:
# intaglobal
# 1,946 posts
# 6,851 followers
# 262 following
# INTA
# Nonprofit organization
# The association of ™ professionals.
# inta.campsite.bio

# %%
def extracting_data(chunk):
    chunk = chunk.strip()
    sparc_chunk = chunk.split('\n')
    user_name = sparc_chunk[0]
    post = int(sparc_chunk[1].split(' post')[0].replace(',', "").replace('K', "000").replace("M", "000000" ), )
    followers = float(sparc_chunk[2].split(' follower')[0].replace(',', "").replace('K', "").replace("M", "" ), )
    if "K" in sparc_chunk[2]:
        followers = int(followers*1000)
    elif "M" in  sparc_chunk[2]:
        followers = int(followers*1000000)
    else:
        followers = int(followers)
    
    following = float(sparc_chunk[3].split(' following')[0].replace(',', "").replace('K', "").replace("M", "" ), )
    if "K" in sparc_chunk[3]:
        following = int(following*1000)
    elif "M" in  sparc_chunk[3]:
        following = int(following*1000000)
    else:
        following = int(following)
    
    name = sparc_chunk[4]
    if (len(sparc_chunk) > 5) :
        org = sparc_chunk[5]
        bio = sparc_chunk[6:]
        # print(org)
        
    else :
        org = "Unknown"
        bio  = ""
        # print(org)
    return { "user_name" : user_name  , "post" : post , "followers" : followers , "following" : following , "name" : name , 
            "org" : org , "bio" : bio }

# %%
parsed_data = []
for chunk in chunks: 
    parsed_chunked = extracting_data(chunk)
    parsed_data.append(parsed_chunked)

# %%
import json 
js = json.dumps(parsed_data , indent=4)

# %%
print(js)
# Out:
# [
#     {
#         "user_name": "intaglobal",
#         "post": 1946,
#         "followers": 6851,
#         "following": 262,
#         "name": "INTA",
#         "org": "Nonprofit organization",
#         "bio": [
#             "The association of \u2122 professionals.",
#             "inta.campsite.bio"
#         ]
#     },
#     {
#         "user_name": "_anujsinghal",
#         "post": 1785,
#         "followers": 681000,
#         "following": 248,
#         "name": "Anuj Singhal",
#         "org": "Digital creator",
#         "bio": [
#             "Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India",
#             "Let\u2019s talk about finance and life",
#             "Contact: Singhalanuj1010@gmail.com",
#             "hindi.cnbctv18.com/market-gurukul"
#         ]
#     },
#     {
#         "user_name": "code_flare",
#         "post": 165,
#         "followers": 216,
#         "following": 10,
#         "name": "The Journey Notebook | Travel | Food Blogger",
#         "org": "Blogger",
#         "bio": [
#             "\ud83d\udccd Exploring places & phases of life \ud83c\udf0d",
#             ".",
#             "\ud83c\udf75 From chai breaks to flight takes \u2708\ufe0f",
#             ".",
#             "\ud83d\udcab Travel | Food | Daily life \ud83c\udf38",
#             "youtube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a"
#         ]
#     },
#     {
#         "user_name": "bangalore_tech_bro",
#         "post": 402,
#         "followers": 12500,
#         "following": 890,
#         "name": "Rahul | HSR Hustler",
#         "org": "Entrepreneur",
#         "bio": [
#             "\ud83d\ude80 Building the next Unicorn in Fintech",
#             "\u2615 3rd Wave Coffee addict",
#             "\ud83d\udcbb Python | React | AI",
#             "\ud83d\udccd HSR Layout, BLR",
#             "linktr.ee/rahulbuilds"
#         ]
#     },
#     {
#         "user_name": "silkboard_survivor",
#         "post": 55,
#         "followers": 1200,
#         "following": 50,
#         "name": "Priya D.",
#         "org": "Public Figure",
#         "bio": [
#             "\ud83d\udea6 Stuck in traffic since 2019",
#             "\ud83c\udf27\ufe0f Loving the Bangalore weather, hating the cabs",
#             "\ud83d\udc0d Data Scientist by day, meme maker by night",
#             "\ud83d\udccd ORR",
#             "bit.ly/my-traffic-rants"
#         ]
#     },
#     {
#         "user_name": "startuphub_blr",
#         "post": 2300,
#         "followers": 45000,
#         "following": 120,
#         "name": "Startup Hub Bangalore",
#         "org": "Media",
#         "bio": [
#             "\ud83e\udd84 News from the Silicon Valley of India",
#             "\ud83d\udce2 Funding alerts, Hiring trends, and Drama",
#             "\ud83d\udce9 DM for features",
#             "startuphub.blr/newsletter"
#         ]
#     },
#     {
#         "user_name": "foodie_in_kora",
#         "post": 890,
#         "followers": 5600,
#         "following": 400,
#         "name": "Sneha | Bangalore Eats",
#         "org": "Food & Drink",
#         "bio": [
#             "Aagrah to Truffles \ud83c\udf54",
#             "Exploring Koramangala's cafe culture \u2615",
#             "DM for collabs",
#             "https://www.google.com/search?q=zomato.com/users/sneha123"
#         ]
#     },
#     {
#         "user_name": "venture_vikram",
#         "post": 120,
#         "followers": 30000,
#         "following": 500,
#         "name": "Vikram | Angel Investor",
#         "org": "Investor",
#         "bio": [
#             "\ud83d\udcb8 Helping founders go 0 to 1",
#             "Ex-Google, Ex-Amazon",
#             "Investing in DeepTech & AI",
#             "\ud83d\udccd Indiranagar",
#             "vikram.vc/pitch-deck"
#         ]
#     },
#     {
#         "user_name": "python_meetup_blr",
#         "post": 60,
#         "followers": 3400,
#         "following": 10,
#         "name": "PyBangalore Community",
#         "org": "Community",
#         "bio": [
#             "\ud83d\udc0d Weekly meetups for Pythonistas",
#             "\ud83d\udccd Cubbon Park | Sundays 4 PM",
#             "Coding + Coffee + Community",
#             "https://www.google.com/search?q=meetup.com/pybangalore"
#         ]
#     },
#     {
#         "user_name": "indiranagar_gossip",
#         "post": 300,
#         "followers": 8900,
#         "following": 20,
#         "name": "Indiranagar Spy",
#         "org": "Personal Blog",
#         "bio": [
#             "Not just about 100ft Road \ud83e\udd2b",
#             "Spilling tea on the best brunches and worst landlords",
#             "Bengaluru",
#             "https://www.google.com/search?q=medium.com/%40indiranagarspy"
#         ]
#     },
#     {
#         "user_name": "ig_arbin07",
#         "post": 50,
#         "followers": 33,
#         "following": 30,
#         "name": "aarbinnn",
#         "org": "Gamer",
#         "bio": [
#             "@dumb.arbin",
#             "\ud83c\udfae: Banana\u300ejuice (IGL\ud83e\udd77)",
#             "Gamer never die, they just respawn\ud83d\ude42\u200d\u2194\ufe0f"
#         ]
#     },
#     {
#         "user_name": "7iiuliiu",
#         "post": 1,
#         "followers": 44,
#         "following": 166,
#         "name": "\ufe0e\ud835\udc04\ufe0e \u2661\ufe0e.",
#         "org": "Unknown",
#         "bio": ""
#     },
#     {
#         "user_name": "katiasales2220",
#         "post": 107,
#         "followers": 219,
#         "following": 1401,
#         "name": "Katia Sales",
#         "org": "Alfabetiza\u00e7\u00e3o e Refor\u00e7o Escolar",
#         "bio": [
#             "Ensino Fundamental I e II",
#             "Prepara\u00e7\u00e3o para Escola Militar",
#             "Portugu\u00eas e Matem\u00e1tica",
#             "Cursando Psicopedagogia Est\u00e1cio"
#         ]
#     }
# ]

# %% [markdown]
# # maximum post

# %%
max = 0
for chunk in parsed_data:
    if (max < chunk['post']):
        max = chunk['post']
        max_posts = chunk
print(max_posts)
# Out:
# {'user_name': 'startuphub_blr', 'post': 2300, 'followers': 45000, 'following': 120, 'name': 'Startup Hub Bangalore', 'org': 'Media', 'bio': ['🦄 News from the Silicon Valley of India', '📢 Funding alerts, Hiring trends, and Drama', '📩 DM for features', 'startuphub.blr/newsletter']}

# %% [markdown]
# # who follows maximimum people

# %%
max = 0
for chunk in parsed_data:
    if (max < chunk['following']):
        max = chunk['following']
        max_posts = chunk
print(max_posts)
# Out:
# {'user_name': 'katiasales2220', 'post': 107, 'followers': 219, 'following': 1401, 'name': 'Katia Sales', 'org': 'Alfabetização e Reforço Escolar', 'bio': ['Ensino Fundamental I e II', 'Preparação para Escola Militar', 'Português e Matemática', 'Cursando Psicopedagogia Estácio']}

# %% [markdown]
# # who has the most followers

# %%
max = 0
for chunk in parsed_data:
    if (max < chunk['followers']):
        max = chunk['followers']
        max_posts = chunk
print(max_posts)
# Out:
# {'user_name': '_anujsinghal', 'post': 1785, 'followers': 681000, 'following': 248, 'name': 'Anuj Singhal', 'org': 'Digital creator', 'bio': ['Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India', 'Let’s talk about finance and life', 'Contact: Singhalanuj1010@gmail.com', 'hindi.cnbctv18.com/market-gurukul']}

# %%
cat  = set()
for chunk in parsed_data:
    cat.add(chunk['org'])
print(len(cat))
# Out:
# 13
